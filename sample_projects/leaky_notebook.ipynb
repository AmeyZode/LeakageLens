# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Hardcoded absolute path (Major Reproducibility Issue)
df = pd.read_csv("C:\\Users\\admin\\dataset.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X = df.drop(columns=["target"])
y = df["target"]

# Preprocessing before split (Critical Preprocessing Leakage)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split missing random_state (Major Reproducibility Issue)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y)

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
